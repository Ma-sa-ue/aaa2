# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = np.load("./sample_80.jpg.npy")
print a.shape
plt.figure(figsize=(12,12))
plt.imshow(a)
#####plt.savefig("/home/uehara/dcgan_tensorflow/lsun/new_breg.png")
# Out:
# (448, 448, 3)

# %%
aaa1 = np.load("./array1_80.npy")
aaa2 = np.load("./array2_80.npy")
aaa3 = np.load("./array3_80.npy")

plt.figure(figsize=(15,8))
plt.plot(aaa1)
plt.plot(aaa2)
plt.show()
plt.figure(figsize=(15,8))
plt.plot(aaa3)
plt.show()
